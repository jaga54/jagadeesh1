# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_excel("C:/Users/Mageshwaran/Documents/duratech/csv files/Exercise Data.xlsx",header=1)
data
# Out:
#     Month  Contribution  Amount won by the bidder  \
# 0       1          2000                     40000
# 1       2          2000                     42000
# 2       3          2000                     45000
# 3       4          2000                     48000
# 4       5          2000                     40000
# 5       6          2000                     42000
# 6       7          2000                     43000
# 7       8          2000                     44000
# 8       9          2000                     40000
# 9      10          2000                     42000
# 10     11          2000                     45000
# 11     12          2000                     48000
# 12     13          2000                     40000
# 13     14          2000                     42000
# 14     15          2000                     43000
# 15     16          2000                     43000
# 16     17          2000                     41000
# 17     18          2000                     42000
# ...

# %%
data["Amount won by the bidder"].describe()
# Out:
# count       25.000000
# mean     43800.000000
# std       2857.738033
# min      40000.000000
# 25%      42000.000000
# 50%      43000.000000
# 75%      45000.000000
# max      50000.000000
# Name: Amount won by the bidder, dtype: float64

# %%
plt.scatter(data["Amount won by the bidder"],data["Net amount recd by Bid winner"])

# %%
data["Amount returned to everyone in the group"].sum()
# Out:
# 6200

# %%
a=data["Amount returned to everyone in the group"].mean()
a
# Out:
# 248.0

# %%
data["Annualized amount received by bidder"]= a+data["Net amount recd by Bid winner"]

# %%
data["Annualized amount received by bidder"].head()
# Out:
# 0    37748.0
# 1    39748.0
# 2    42748.0
# 3    45748.0
# 4    37748.0
# Name: Annualized amount received by bidder, dtype: float64

# %%
data
# Out:
#     Month  Contribution  Amount won by the bidder  \
# 0       1          2000                     40000
# 1       2          2000                     42000
# 2       3          2000                     45000
# 3       4          2000                     48000
# 4       5          2000                     40000
# 5       6          2000                     42000
# 6       7          2000                     43000
# 7       8          2000                     44000
# 8       9          2000                     40000
# 9      10          2000                     42000
# 10     11          2000                     45000
# 11     12          2000                     48000
# 12     13          2000                     40000
# 13     14          2000                     42000
# 14     15          2000                     43000
# 15     16          2000                     43000
# 16     17          2000                     41000
# 17     18          2000                     42000
# ...

# %%
a=data["Amount returned to everyone in the group"]/25
a
# Out:
# 0     16.0
# 1     12.8
# 2      8.0
# 3      3.2
# 4     16.0
# 5     12.8
# 6     11.2
# 7      9.6
# 8     16.0
# 9     12.8
# 10     8.0
# 11     3.2
# 12    16.0
# 13    12.8
# 14    11.2
# 15    11.2
# 16    14.4
# 17    12.8
# 18     8.0
# 19     8.0
# 20     9.6
# 21     6.4
# 22     4.8
# 23     3.2
# 24     0.0
# Name: Amount returned to everyone in the group, dtype: float64

# %%
data["Each month of bid winner"]=a+data["Net amount recd by Bid winner"]

# %%
data
# Out:
#     Month  Contribution  Amount won by the bidder  \
# 0       1          2000                     40000
# 1       2          2000                     42000
# 2       3          2000                     45000
# 3       4          2000                     48000
# 4       5          2000                     40000
# 5       6          2000                     42000
# 6       7          2000                     43000
# 7       8          2000                     44000
# 8       9          2000                     40000
# 9      10          2000                     42000
# 10     11          2000                     45000
# 11     12          2000                     48000
# 12     13          2000                     40000
# 13     14          2000                     42000
# 14     15          2000                     43000
# 15     16          2000                     43000
# 16     17          2000                     41000
# 17     18          2000                     42000
# ...

# %%
data["% Each month bid winner"]=(data["Each month of bid winner"]/50000)*100

# %%
data["% Each month bid winner"]
# Out:
# 0     75.0320
# 1     79.0256
# 2     85.0160
# 3     91.0064
# 4     75.0320
# 5     79.0256
# 6     81.0224
# 7     83.0192
# 8     75.0320
# 9     79.0256
# 10    85.0160
# 11    91.0064
# 12    75.0320
# 13    79.0256
# 14    81.0224
# 15    81.0224
# 16    77.0288
# 17    79.0256
# 18    85.0160
# 19    85.0160
# 20    83.0192
# 21    87.0128
# 22    89.0096
# 23    91.0064
# 24    95.0000
# Name: % Each month bid winner, dtype: float64

# %%
data.head()
# Out:
#    Month  Contribution  Amount won by the bidder  \
# 0      1          2000                     40000
# 1      2          2000                     42000
# 2      3          2000                     45000
# 3      4          2000                     48000
# 4      5          2000                     40000
#
#    Chit fund organizer commission  Net amount recd by Bid winner  \
# 0                            2500                          37500
# 1                            2500                          39500
# 2                            2500                          42500
# 3                            2500                          45500
# 4                            2500                          37500
#
#    Amount returned to everyone in the group  \
# 0                                       400
# 1                                       320
# 2                                       200
# 3                                        80
# 4                                       400
#
# ...

# %%
a=data["Amount returned to everyone in the group"]/25
b=a.sum()

# %%
data["Annualized return of chitfund participant"]=b

# %% [markdown]
# # Annualized return of the person bids in the first month

# %%
data["Annualized amount received by bidder"][(data["Month"]==1)&(data["Annualized amount received by bidder"])]
# Out:
# 0    37748.0
# Name: Annualized amount received by bidder, dtype: float64

# %% [markdown]
# # Annualized return of the person bids in the last month

# %%
data["Annualized amount received by bidder"][(data["Month"]==25)&(data["Annualized amount received by bidder"])]
# Out:
# 24    47748.0
# Name: Annualized amount received by bidder, dtype: float64

# %% [markdown]
# # Annualized return of chit fund participant

# %%
data["Amount returned to everyone in the group"].sum()
# Out:
# 6200

# %% [markdown]
# # Annualized return of chit fund of each participant

# %%
a=data["Amount returned to everyone in the group"]/25
b=a.sum()
b
# Out:
# 248.0

# %% [markdown]
# # Return % for Each month's bid winner

# %%
data["% Each month bid winner"]
# Out:
# 0     75.0320
# 1     79.0256
# 2     85.0160
# 3     91.0064
# 4     75.0320
# 5     79.0256
# 6     81.0224
# 7     83.0192
# 8     75.0320
# 9     79.0256
# 10    85.0160
# 11    91.0064
# 12    75.0320
# 13    79.0256
# 14    81.0224
# 15    81.0224
# 16    77.0288
# 17    79.0256
# 18    85.0160
# 19    85.0160
# 20    83.0192
# 21    87.0128
# 22    89.0096
# 23    91.0064
# 24    95.0000
# Name: % Each month bid winner, dtype: float64

# %%
data["% Each month bid winner"].plot(kind="bar")
